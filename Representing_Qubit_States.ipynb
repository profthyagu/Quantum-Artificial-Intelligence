# %% [markdown]
# ## Representing Qubit States

# %%
# Importing required packages
from qiskit import QuantumRegister, QuantumCircuit, assemble
from qiskit.visualization import plot_histogram, plot_bloch_multivector
from math import sqrt, pi
from qiskit_aer import Aer
# Specifying the quantum simulator for simulating the circuits
sim = Aer.get_backend('aer_simulator')

# %% [markdown]
# ### Bloch Sphere
# ![bloch_sphere](data:image/png;base64,...)

# %% [markdown]
# ### Representing | 0 > statevector

# %%
# Creating a qubit register
q = QuantumRegister(1) 

# Making the qubit a part of the quantum circuit
# This create a quantum circuit with one qubit
qc = QuantumCircuit(q)

# Qiskit by default initialises |0> state
# Displaying the quantum circuit
qc.draw(output="mpl")

# %%
# Simulator saves the statevector
qc.save_statevector()   

# Run the simulation and return the result
result = sim.run(qc).result()

# %%
# Get the output state vector
output_state = result.get_statevector()

# Display the output state vector
print(output_state)
# Out:
# Statevector([1.+0.j, 0.+0.j],
#             dims=(2,))

# %%
# Measure and display the quantum circuit 
qc.measure_all()
qc.draw(output="mpl")

# %%
# Probability of the output
counts = result.get_counts()
plot_histogram(counts)

# %%
# Representing the qubit on a Bloch Sphere
plot_bloch_multivector(output_state)

# %% [markdown]
# ### Representing | 1 > statevector

# %%
# Create a quantum circuit with one qubit
qc = QuantumCircuit(1)  

# Define initial_state as |1>
initial_state = [0,1]   

# Apply initialisation operation to the 0th qubit
qc.initialize(initial_state, 0) 

# Displaying the quantum circuit
qc.draw(output="mpl")

# %%
# Simulator saves the statevector
qc.save_statevector()   

# Run the simulation and return the result
result = sim.run(qc).result()

# %%
# Get the output state vector
output_state = result.get_statevector()

# Display the output state vector
print(output_state)
# Out:
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))

# %%
# Measure and display the quantum circuit 
qc.measure_all()
qc.draw(output="mpl")

# %%
# Probability of the output state
counts = result.get_counts()
plot_histogram(counts)

# %%
# Representing the qubit on a Bloch Sphere
plot_bloch_multivector(output_state)

# %% [markdown]
# ### Representing | + > statevector

# %%
 # Create a quantum circuit with one qubit
qc = QuantumCircuit(1) 

# Define initial_state as |+>
initial_state = [1/sqrt(2),1/sqrt(2)]   

# Apply initialisation operation to the 0th qubit
qc.initialize(initial_state, 0) 

# Displaying the quantum circuit
qc.draw(output="mpl")

# %%
# Simulator saves the statevector
qc.save_statevector()   

# Run the simulation and return the result
result = sim.run(qc).result()

# %%
# Get the output state vector
output_state = result.get_statevector()

# Display the output state vector
print(output_state)
# Out:
# Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))

# %%
# Measure and display the quantum circuit 
qc.measure_all()
qc.draw(output="mpl")

# %%
# Probability of the output state
counts = result.get_counts()
plot_histogram(counts)

# %%
# Representing the qubit on a Bloch Sphere
plot_bloch_multivector(output_state)

# %% [markdown]
# ### Representing | - > statevector

# %%
# Create a quantum circuit with one qubit
qc = QuantumCircuit(1)

# Define initial_state as |->
initial_state = [1/sqrt(2),-1/sqrt(2)]   

# Apply initialisation operation to the 0th qubit
qc.initialize(initial_state, 0)

# Displaying the quantum circuit
qc.draw(output="mpl")

# %%
# Simulator saves the statevector
qc.save_statevector()    

# Run the simulation and return the result
result = sim.run(qc).result()

# %%
# Get the output state vector
output_state = result.get_statevector()

# Display the output state vector
print(output_state)
# Out:
# Statevector([ 0.70710678+0.j, -0.70710678+0.j],
#             dims=(2,))

# %%
# Measure and display the quantum circuit 
qc.measure_all()
qc.draw(output="mpl")

# %%
# Probability of the output state
counts = result.get_counts()
plot_histogram(counts)

# %%
# Representing the qubit on a Bloch Sphere
plot_bloch_multivector(output_state)

# %% [markdown]
# ### Representing | i+ > statevector

# %%
# Create a quantum circuit with one qubit
qc = QuantumCircuit(1)  

# Define initial_state as |i+>
initial_state = [1/sqrt(2),1.j/sqrt(2)]  

# Apply initialisation operation to the 0th qubit
qc.initialize(initial_state, 0)

# Displaying the quantum circuit
qc.draw(output="mpl")

# %%
# Simulator saves the statevector
qc.save_statevector()   

# Run the simulation and return the result
result = sim.run(qc).result()

# %%
# Get the output state vector
output_state = result.get_statevector()

# Display the output state vector
print(output_state)
# Out:
# Statevector([0.70710678+0.j        , 0.        +0.70710678j],
#             dims=(2,))

# %%
# Measure and display the quantum circuit 
qc.measure_all()
qc.draw(output="mpl")

# %%
# Probability of the output state
counts = result.get_counts()
plot_histogram(counts)

# %%
# Representing the qubit on a Bloch Sphere
plot_bloch_multivector(output_state)

# %% [markdown]
# ### Representing | i- > statevector

# %%
# Create a quantum circuit with one qubit
qc = QuantumCircuit(1)  

# Define initial_state as |i->
initial_state = [1/sqrt(2),-1.j/sqrt(2)]  

# Apply initialisation operation to the 0th qubit
qc.initialize(initial_state, 0)

# Displaying the quantum circuit
qc.draw(output="mpl")

# %%
# Simulator saves the statevector
qc.save_statevector()   

# Run the simulation and return the result
result = sim.run(qc).result()

# %%
# Get the output state vector
output_state = result.get_statevector()

# Display the output state vector
print(output_state)
# Out:
# Statevector([ 0.70710678+0.j        , -0.        -0.70710678j],
#             dims=(2,))

# %%
# Measure and display the quantum circuit 
qc.measure_all()
qc.draw(output="mpl")

# %%
# Probability of the output state
counts = result.get_counts()
plot_histogram(counts)

# %%
# Representing the qubit on a Bloch Sphere
plot_bloch_multivector(output_state)

# %% [markdown]
# ## References
# https://github.com/developer-student-club-thapar/Quantum-Computing/blob/main/1.%20Representing%20a%20qubit/3.%20representing_qubit_states.ipynb

# %% [markdown]
# https://www.youtube.com/watch?v=5Sz9I2p328E
